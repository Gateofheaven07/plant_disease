# %%
import os
import json
from pathlib import Path
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.class_weight import compute_class_weight
import joblib

# =========================
# Konfigurasi
# =========================
# Bisa override via env: DATASET_NAME, BATCH_SIZE, EPOCHS_STAGE1, EPOCHS_STAGE2
DATASET_CANDIDATES = [
    os.environ.get("DATASET_NAME", "DATASET_DAUN"),
    "DATASET-DAUN",  # fallback lain yang sering dipakai
]
IMG_SIZE = (224, 224)
BATCH_SIZE = int(os.environ.get("BATCH_SIZE", 32))
SEED = 1337
EPOCHS_STAGE1 = int(os.environ.get("EPOCHS_STAGE1", 10))
EPOCHS_STAGE2 = int(os.environ.get("EPOCHS_STAGE2", 10))

ARTIFACTS_DIR = Path("artifacts"); ARTIFACTS_DIR.mkdir(exist_ok=True)
MODEL_PATH = Path("model.h5")
RF_PATH = Path("rf.joblib")


# =========================
# Util: cari folder dataset dengan aman
# =========================
def find_dataset_dir(names: list[str]) -> Path:
    """
    Cari salah satu nama folder dalam 'names' mulai dari CWD, menelusuri parent,
    lalu rglob ke subfolder. Return absolute Path. Raise FileNotFoundError bila tidak ketemu.
    """
    start = Path.cwd()

    # cek di CWD + parent
    for base in (start, *start.parents):
        for name in names:
            cand = base / name
            if cand.is_dir():
                return cand.resolve()

    # cek rekursif di bawah CWD
    for name in names:
        for cand in start.rglob(name):
            if cand.is_dir():
                return cand.resolve()

    raise FileNotFoundError(
        "Tidak menemukan folder dataset. Dicari menggunakan kandidat nama: "
        f"{names}\nCWD saat ini: {start}\n"
        "Solusi: pindahkan folder dataset ke CWD ini, atau set env DATASET_NAME="
        "<nama_folder_dataset_anda> saat menjalankan script."
    )


# =========================
# Muat dataset + validasi
# =========================
print("Mencari folder dataset…")
DATA_DIR = find_dataset_dir(DATASET_CANDIDATES)
print("DATA_DIR =", DATA_DIR)

# Validasi struktur: harus ada subfolder kelas dan ada gambar
subdirs = [p for p in DATA_DIR.iterdir() if p.is_dir()]
if not subdirs:
    raise RuntimeError(
        f"Folder {DATA_DIR} tidak berisi subfolder kelas.\n"
        f"Struktur harus: {DATA_DIR.name}/<Nama_Kelas>/*.jpg|*.png"
    )
IMG_EXTS = {".jpg", ".jpeg", ".png", ".bmp"}
num_imgs = sum(1 for p in DATA_DIR.rglob("*") if p.suffix.lower() in IMG_EXTS)
if num_imgs == 0:
    raise RuntimeError(f"Tidak menemukan file gambar (.jpg/.png/.bmp) di {DATA_DIR}.")

print(f"Jumlah kelas: {len(subdirs)}; Perkiraan gambar: {num_imgs}")

abs_data_dir = str(DATA_DIR)  # Keras butuh string path

train_ds = keras.utils.image_dataset_from_directory(
    abs_data_dir,
    labels="inferred",
    label_mode="int",
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
)
val_ds = keras.utils.image_dataset_from_directory(
    abs_data_dir,
    labels="inferred",
    label_mode="int",
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Kelas:", class_names)

# Simpan mapping id->nama kelas
with (ARTIFACTS_DIR / "class_indices.json").open("w", encoding="utf-8") as f:
    json.dump({i: n for i, n in enumerate(class_names)}, f, ensure_ascii=False, indent=2)

# Optimasi pipeline
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000, seed=SEED).prefetch(AUTOTUNE)
val_ds   = val_ds.cache().prefetch(AUTOTUNE)

# =========================
# Model: Augmentasi + MobileNetV2
# =========================
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.05),
        layers.RandomZoom(0.1),
        layers.RandomContrast(0.1),
    ],
    name="augmentation",
)

base = keras.applications.MobileNetV2(
    input_shape=IMG_SIZE + (3,),
    include_top=False,
    weights="imagenet",
)
base.trainable = False  # Stage 1: beku

inputs = keras.Input(shape=IMG_SIZE + (3,))
x = data_augmentation(inputs)
x = keras.applications.mobilenet_v2.preprocess_input(x)
x = base(x, training=False)
x = layers.GlobalAveragePooling2D(name="gap")(x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(num_classes, activation="softmax", name="preds")(x)
model = keras.Model(inputs, outputs, name="leaf_disease_cnn")

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# =========================
# Class weights (atasi ketidakseimbangan)
# =========================
labels_collected = []
tmp_ds = keras.utils.image_dataset_from_directory(
    abs_data_dir,
    labels="inferred",
    label_mode="int",
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
)
for _, yb in tmp_ds:
    labels_collected.append(yb.numpy())
y_train_all = np.concatenate(labels_collected)
cw_vals = compute_class_weight(
    class_weight="balanced",
    classes=np.arange(num_classes),
    y=y_train_all,
)
class_weight = {i: float(w) for i, w in enumerate(cw_vals)}
print("Class weights:", class_weight)

# =========================
# Stage 1 (feature extractor frozen)
# =========================
ckpt = keras.callbacks.ModelCheckpoint(
    str(MODEL_PATH), monitor="val_accuracy", mode="max",
    save_best_only=True, save_weights_only=False
)
early = keras.callbacks.EarlyStopping(patience=6, restore_best_weights=True)

print("\n=== Stage 1: training (backbone frozen) ===")
model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_STAGE1,
    class_weight=class_weight,
    callbacks=[ckpt, early],
)

# =========================
# Stage 2 (fine-tuning top layers)
# =========================
print("\n=== Stage 2: fine-tuning (unfreeze sebagian) ===")
backbone = None
for l in model.layers:
    if "mobilenet" in l.name.lower():
        backbone = l
        break
if backbone is None:
    raise RuntimeError("Backbone MobileNetV2 tidak ditemukan dalam model.")

backbone.trainable = True
for l in backbone.layers[:-40]:
    l.trainable = False

model.compile(
    optimizer=keras.optimizers.Adam(1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_STAGE2,   # default 10
    class_weight=class_weight,
    callbacks=[ckpt, early],
)

# Muat model terbaik & evaluasi
best = keras.models.load_model(str(MODEL_PATH))
val_loss, val_acc = best.evaluate(val_ds, verbose=0)
print(f"Best val acc: {val_acc:.4f}")

# =========================
# RandomForest dari embedding CNN
# =========================
print("\n=== Training RandomForest (embeddings from CNN) ===")
emb_extractor = keras.Model(inputs=best.input, outputs=best.get_layer("gap").output)

def ds_to_embeddings(ds):
    X, y = [], []
    for xb, yb in ds:
        emb = emb_extractor.predict(xb, verbose=0)
        X.append(emb); y.append(yb.numpy())
    return np.vstack(X), np.concatenate(y)

X_train, y_train = ds_to_embeddings(train_ds)
X_val,   y_val   = ds_to_embeddings(val_ds)

rf = RandomForestClassifier(
    n_estimators=400,
    n_jobs=-1,
    class_weight="balanced_subsample",
    random_state=SEED,
)
rf.fit(X_train, y_train)
print("RF val acc:", rf.score(X_val, y_val))
joblib.dump(rf, RF_PATH)

# =========================
# Disease info JSON (skeleton bila belum ada)
# =========================
info_path = ARTIFACTS_DIR / "disease_info.json"
if not info_path.exists():
    template = {
        c: {
            "nama": c.replace("_", " "),
            "deskripsi": "",
            "pengobatan": "",
            "perawatan": "",
            "pencegahan": "",
        }
        for c in class_names
    }
    with info_path.open("w", encoding="utf-8") as f:
        json.dump(template, f, ensure_ascii=False, indent=2)
    print(f"Created skeleton: {info_path}")
else:
    print(f"Using existing: {info_path}")

print("\nTraining selesai. Tersimpan:")
print(" -", MODEL_PATH.resolve())
print(" -", RF_PATH.resolve())
print(" -", (ARTIFACTS_DIR / 'class_indices.json').resolve())
print(" -", info_path.resolve())
# Out:
# Mencari folder dataset…
# DATA_DIR = C:\Users\User\Project ML\Project\DATASET_DAUN
# Jumlah kelas: 25; Perkiraan gambar: 30647
# Found 30647 files belonging to 25 classes.
# Using 24518 files for training.
# Found 30647 files belonging to 25 classes.
# Using 6129 files for validation.
# Kelas: ['Daun_Anggur_Busuk', 'Daun_Anggur_Esca', 'Daun_Anggur_Hawar', 'Daun_Anggur_Sehat', 'Daun_Apel_Busuk', 'Daun_Apel_Karat', 'Daun_Apel_Kudis', 'Daun_Apel_Sehat', 'Daun_Jagung_Hawar', 'Daun_Jagung_Jamur', 'Daun_Jagung_Karat', 'Daun_Jagung_Sehat', 'Daun_Kentang_Hawar_Muda', 'Daun_Kentang_Hawar_Tua', 'Daun_Kentang_Sehat', 'Daun_Tomat_Bakteri', 'Daun_Tomat_Hawar_Muda', 'Daun_Tomat_Hawar_Tua', 'Daun_Tomat_Jamur_Fulva', 'Daun_Tomat_Jamur_Septoria', 'Daun_Tomat_Jamur_Target_spot', 'Daun_Tomat_Sehat', 'Daun_Tomat_Tungau_Labalaba', 'Daun_Tomat_Virus_Begomovirus', 'Daun_Tomat_Virus_Mosaicvirus']
# Found 30647 files belonging to 25 classes.
# Using 24518 files for training.
# Class weights: {0: 1.0765312843029637, 1: 0.8940018231540565, 2: 1.1717084826762245, 3: 3.055202492211838, 4: 2.0431666666666666, 5: 5.081450777202073, 6: 2.0431666666666666, 7: 0.7567283950617284, 8: 1.2736623376623377, 9: 2.4579448621553883, 10: 1.0848672566371682, 11: 1.0812789415656008, 12: 1.2541176470588236, 13: 1.2720103761348898, 14: 10.110515463917526, 15: 0.5848062015503876, 16: 1.2445685279187817, 17: 0.6667029231815091, 18: 1.293825857519789, 19: 0.7142898761835397, 20: 0.8787813620071685, 21: 0.7852041633306646, 22: 0.7544, 23: 0.2295692883895131, 24: 3.645799256505576}
#
# === Stage 1: training (backbone frozen) ===
# Epoch 1/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 0s 699ms/step - accuracy: 0.6559 - loss: 1.2534
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 915s 977ms/step - accuracy: 0.7880 - loss: 0.7274 - val_accuracy: 0.8776 - val_loss: 0.3856
# Epoch 2/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 0s 816ms/step - accuracy: 0.8807 - loss: 0.3521
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 755s 985ms/step - accuracy: 0.8867 - loss: 0.3386 - val_accuracy: 0.9018 - val_loss: 0.3007
# Epoch 3/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 783s 1s/step - accuracy: 0.9006 - loss: 0.2756 - val_accuracy: 0.8992 - val_loss: 0.3011
# Epoch 4/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 0s 825ms/step - accuracy: 0.9128 - loss: 0.2438
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 765s 997ms/step - accuracy: 0.9119 - loss: 0.2477 - val_accuracy: 0.9104 - val_loss: 0.2651
# Epoch 5/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9143 - loss: 0.2317
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 667s 869ms/step - accuracy: 0.9139 - loss: 0.2322 - val_accuracy: 0.9140 - val_loss: 0.2472
# Epoch 6/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 0s 650ms/step - accuracy: 0.9188 - loss: 0.2128
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 605s 789ms/step - accuracy: 0.9204 - loss: 0.2160 - val_accuracy: 0.9295 - val_loss: 0.2179
# Epoch 7/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 659s 858ms/step - accuracy: 0.9210 - loss: 0.2120 - val_accuracy: 0.9171 - val_loss: 0.2407
# Epoch 8/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 592s 771ms/step - accuracy: 0.9247 - loss: 0.2038 - val_accuracy: 0.9287 - val_loss: 0.2188
# Epoch 9/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 614s 801ms/step - accuracy: 0.9251 - loss: 0.1960 - val_accuracy: 0.9119 - val_loss: 0.2544
# Epoch 10/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 599s 782ms/step - accuracy: 0.9286 - loss: 0.1885 - val_accuracy: 0.9137 - val_loss: 0.2535
#
# === Stage 2: fine-tuning (unfreeze sebagian) ===
# Epoch 1/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 812s 1s/step - accuracy: 0.9087 - loss: 0.2716 - val_accuracy: 0.7956 - val_loss: 0.8330
# Epoch 2/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 796s 1s/step - accuracy: 0.9609 - loss: 0.1057 - val_accuracy: 0.8956 - val_loss: 0.3600
# Epoch 3/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 801s 1s/step - accuracy: 0.9702 - loss: 0.0789 - val_accuracy: 0.8667 - val_loss: 0.4992
# Epoch 4/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 0s 885ms/step - accuracy: 0.9798 - loss: 0.0507
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 781s 1s/step - accuracy: 0.9799 - loss: 0.0512 - val_accuracy: 0.9315 - val_loss: 0.2226
# Epoch 5/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 732s 954ms/step - accuracy: 0.9819 - loss: 0.0496 - val_accuracy: 0.8359 - val_loss: 0.8737
# Epoch 6/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 0s 878ms/step - accuracy: 0.9866 - loss: 0.0358
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 777s 1s/step - accuracy: 0.9880 - loss: 0.0322 - val_accuracy: 0.9608 - val_loss: 0.1332
# Epoch 7/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 775s 1s/step - accuracy: 0.9883 - loss: 0.0320 - val_accuracy: 0.9602 - val_loss: 0.1360
# Epoch 8/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 759s 989ms/step - accuracy: 0.9880 - loss: 0.0349 - val_accuracy: 0.9431 - val_loss: 0.2392
# Epoch 9/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 735s 958ms/step - accuracy: 0.9909 - loss: 0.0239 - val_accuracy: 0.9331 - val_loss: 0.2637
# Epoch 10/10
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 758s 988ms/step - accuracy: 0.9925 - loss: 0.0215 - val_accuracy: 0.9346 - val_loss: 0.2829
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 227
#     218 model.fit(
#     219     train_ds,
#     220     validation_data=val_ds,
#    (...)    223     callbacks=[ckpt, early],
#     224 )
#     226 # Muat model terbaik & evaluasi
# --> 227 best = keras.models.load_model(str(MODEL_PATH))
#     228 val_loss, val_acc = best.evaluate(val_ds, verbose=0)
#     229 print(f"Best val acc: {val_acc:.4f}")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
#     202 elif str(filepath).endswith(".keras"):
#     203     raise ValueError(
#     204         f"File not found: filepath={filepath}. "
#     205         "Please ensure the file is an accessible `.keras` "
#     206         "zip file."
#     207     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:137, in load_model_from_hdf5(filepath, custom_objects, compile, safe_mode)
#     135 safe_mode_scope = serialization_lib.SafeModeScope(safe_mode)
#     136 with legacy_scope, safe_mode_scope:
# --> 137     model = saving_utils.model_from_config(
#     138         model_config, custom_objects=custom_objects
#     139     )
#     141     # set weights
#     142     load_weights_from_hdf5_group(f["model_weights"], model)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:83, in model_from_config(config, custom_objects)
#      80         function_dict["config"]["closure"] = function_config[2]
#      81         config["config"]["function"] = function_dict
# ---> 83 return serialization.deserialize_keras_object(
#      84     config,
#      85     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      86     custom_objects=custom_objects,
#      87     printable_module_name="layer",
#      88 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\legacy\saving\serialization.py:488, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     485 custom_objects = custom_objects or {}
#     487 if "custom_objects" in arg_spec.args:
# --> 488     deserialized_obj = cls.from_config(
#     489         cls_config,
#     490         custom_objects={
#     491             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     492             **custom_objects,
#     493         },
#     494     )
#     495 else:
#     496     with object_registration.CustomObjectScope(custom_objects):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\models\model.py:660, in Model.from_config(cls, config, custom_objects)
#     655 if is_functional_config and revivable_as_functional:
#     656     # Revive Functional model
#     657     # (but not Functional subclasses with a custom __init__)
#     658     from keras.src.models.functional import functional_from_config
# --> 660     return functional_from_config(
#     661         cls, config, custom_objects=custom_objects
#     662     )
#     664 # Either the model has a custom __init__, or the config
#     665 # does not contain all the information necessary to
#     666 # revive a Functional model. This happens when the user creates
#    (...)    669 # In this case, we fall back to provide all config into the
#     670 # constructor of the class.
#     671 try:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\models\functional.py:558, in functional_from_config(cls, config, custom_objects)
#     556 # First, we create all layers and enqueue nodes to be processed
#     557 for layer_data in functional_config["layers"]:
# --> 558     process_layer(layer_data)
#     560 # Then we process nodes in order of layer depth.
#     561 # Nodes that cannot yet be processed (if the inbound node
#     562 # does not yet exist) are re-enqueued, and the process
#     563 # is repeated until all nodes are processed.
#     564 while unprocessed_nodes:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\models\functional.py:521, in functional_from_config.<locals>.process_layer(layer_data)
#     517 # Instantiate layer.
#     518 if "module" not in layer_data:
#     519     # Legacy format deserialization (no "module" key)
#     520     # used for H5 and SavedModel formats
# --> 521     layer = saving_utils.model_from_config(
#     522         layer_data, custom_objects=custom_objects
#     523     )
#     524 else:
#     525     layer = serialization_lib.deserialize_keras_object(
#     526         layer_data, custom_objects=custom_objects
#     527     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:83, in model_from_config(config, custom_objects)
#      80         function_dict["config"]["closure"] = function_config[2]
#      81         config["config"]["function"] = function_dict
# ---> 83 return serialization.deserialize_keras_object(
#      84     config,
#      85     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      86     custom_objects=custom_objects,
#      87     printable_module_name="layer",
#      88 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\legacy\saving\serialization.py:472, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     469 if isinstance(identifier, dict):
#     470     # In this case we are dealing with a Keras config dictionary.
#     471     config = identifier
# --> 472     (cls, cls_config) = class_and_config_for_serialized_keras_object(
#     473         config, module_objects, custom_objects, printable_module_name
#     474     )
#     476     # If this object has already been loaded (i.e. it's shared between
#     477     # multiple objects), return the already-loaded object.
#     478     shared_object_id = config.get(SHARED_OBJECT_KEY)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\legacy\saving\serialization.py:353, in class_and_config_for_serialized_keras_object(config, module_objects, custom_objects, printable_module_name)
#     349 cls = object_registration.get_registered_object(
#     350     class_name, custom_objects, module_objects
#     351 )
#     352 if cls is None:
# --> 353     raise ValueError(
#     354         f"Unknown {printable_module_name}: '{class_name}'. "
#     355         "Please ensure you are using a `keras.utils.custom_object_scope` "
#     356         "and that this object is included in the scope. See "
#     357         "https://www.tensorflow.org/guide/keras/save_and_serialize"
#     358         "#registering_the_custom_object for details."
#     359     )
#     361 cls_config = config["config"]
#     362 # Check if `cls_config` is a list. If it is a list, return the class and the
#     363 # associated class configs for recursively deserialization. This case will
#     364 # happen on the old version of sequential model (e.g. `keras_version` ==
#     365 # "2.0.6"), which is serialized in a different structure, for example
#     366 # "{'class_name': 'Sequential',
#     367 #   'config': [{'class_name': 'Embedding', 'config': ...}, {}, ...]}".
#
# ValueError: Unknown layer: 'TrueDivide'. Please ensure you are using a `keras.utils.custom_object_scope` and that this object is included in the scope. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.
